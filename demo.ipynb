# %% [markdown]
# Temporary dev note: passwords configured to be stored in plaintext in MongoDB for testing only. DO NOT USE IN PRODUCTION.

# %% [markdown]
# Ensure this setting is reverted to bcrypt hashing before deploying.

# %%
print("hello")
print("my name is greenie")
# Out:
# hello
# my name is greenie
